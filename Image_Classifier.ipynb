# %% [markdown]
# <h1 style="color:#ffc0cb;font-size:70px;font-family:Georgia;text-align:center;"><strong>Personal Project</strong></h1>
# <h2 style="color:#ffc0cb;font-size:70px;font-family:Georgia;text-align:center;"><strong>Classify Images of Colon Cancer</strong></h2>
#
# ### <b>Author Name: Nguyen Dang Huynh Chau</b>
#
# ![54776862.jpeg](attachment:54776862.jpeg)

# %% [markdown]
# <h1 style="color:#ffc0cb;font-size:40px;font-family:Georgia;text-align:center;"><strong> 📜 Table of Content</strong></h1>
#
# ### 1. [Data Preparation](#1)
#
# 1.1 [Introduction](#1.1)
#
# 1.2 [Target question for insights](#1.2)
#
# 1.3 [Importing Necessary Libraries and datasets](#1.3)
#
# 1.4 [Data Retrieving](#1.4)
#
# 1.5 [Data information](#1.5)
#
# <br>
#
# ### 2. [Data Cleaning](#2)
#
# 2.1 [About This Dataset](#2.1)
#
# 2.2 [Data preprocessing](#2.2)
#
# > - 2.2.1 [Drop column `ID` and `Insurance`](#2.2.1)
# > - 2.2.2 [Rename column `Sepssis`](#2.2.2)
# > - 2.2.3 [Convert `Sepsis` in to binary number](#2.2.3)
# > - 2.2.4 [Drop Duplicate](#2.2.4)
# > - 2.2.5 [Convert Data Type](#2.2.5)
#
# 2.3 [Drop column](#2.3)
#
# > - 2.3.1 [Check correllation for dropping](#2.3.1)
# > - 2.3.2 [Check missing values for dropping](#2.3.2)
#
# 2.4 [Upper Case the content](#2.4)
#
# 2.5 [Extra-whitespaces](#2.5)
#
# 2.6 [Descriptive statistics for Central Tendency](#2.6)
#
# > - 2.6.1 [Overview statistics](#2.6.1)
# > - 2.6.2 [Domain Knowledge](#2.6.2)
# > - 2.6.3 [Detect Outliers](#2.6.2)
#
# 2.7 [Save The Intermediate Data](#2.8)
#
# <br>
#
# ### 3. [Data exploration (EDA)](#3)
#
# 3.1 [Overall look on target variable](#3.1)
#
# > - 3.1.1 [Distribution of Sepsis](#3.1.1)
# > - 3.1.2 [Proportion of Sepsis](#3.1.1)
#
# 3.2 [Frequency of each corresponiding Target variable type](#3.2)
#
# > - 3.2.1 [How old are they?](#3.2.1)
# > - 3.2.2 [How much they weight?](#3.2.2)
# > - 3.2.3 [How high PL (Blood Work Result-1 (mu U/ml)) that the Sepsis is likely to get?](#3.2.3)
# > - 3.2.4 [How high PR ((Blood Pressure (mm Hg)) that the Sepsis is likely to get?](#3.2.4)
# > - 3.2.5 [How high SK (Blood Work Result-2 (mm) that the Sepsis is likely to get?](#3.2.5)
# > - 3.2.6 [How high TS (Blood Work Result-3 (mu U/ml)) that the Sepsis is likely to get?](#3.2.6)
# > - 3.2.7 [How high BD2 (Blood Work Result-4 (mu U/ml)) that the Sepsis is likely to get?](#3.2.7)
# > - 3.2.8 [How high BD2 (Blood Work Result-4 (mu U/ml)) that the Sepsis is likely to get?](#3.2.8)
# > - 3.2.9 [Scatter matrix](#3.2.8)
#
# 3.3 [Statistical Test for Correlation](#3.3)
#
# 3.4 [Summary](#3.3)
#
# <br>
#
# ### 4. [Feature Engineering](#4)
#
# 4.1 [Class Imbalancing](#4.1)
#
# 4.2 [Splitting the training data](#4.2)
#
# 4.3 [Feature Scaling](#4.3)
#
#
#
# <br>
#
# ### 5. [Model Building](#5)
#
# 5.1 [Logistic Regression](#5.1)
#
# > - 5.1.1 [Train Model](#5.1.1)
# > - 5.1.2 [Model Evaluation](#5.1.2)
# > - 5.1.3 [Hypertuning parameter](#5.1.3)
# > - 5.1.4 [Retrain](#5.1.4)
# > - 5.1.5 [Conclusion](#5.1.5)
#
# 5.2 [Decision Tree](#5.2)
#
# > - 5.2.1 [Train Model](#5.2.1)
# > - 5.2.2 [Hypertuning & Pruning](#5.2.2)
#
# > - 5.2.2.a [Post-Pruning](#5.2.2.a)
# > - 5.2.2.b [Pre-Pruning](#5.2.2.b)
# > - 5.2.2.c [Hypertuning parameter](#5.2.2.c)
#
# > - 5.2.3 [Hypertuning parameter](#5.2.3)
# > - 5.2.4 [Conclusion](#5.2.3)
#
# 5.3 [Random Forest](#5.3)
#
# > - 5.3.1 [Train Model](#5.3.1)
# > - 5.3.2 [Model Evaluation](#5.3.2)
# > - 5.3.3 [Hypertuning parameter](#5.3.3)
# > - 5.3.4 [Retrain](#5.3.4)
# > - 5.3.5 [Conclusion](#5.3.5)
#
# <br>
#
# ### 6. [Conculsions](#5)
#
# <br>
#
# ### 7. [References](#7)
#
# <br>
#
# ### 8. [Appendix](#8)
#
# <hr>

# %% [markdown]
# <a id="1"></a>
# <h1 style="color:#ffc0cb;font-size:40px;font-family:Georgia;text-align:center;"><strong> ✍️ 1. Data Preparation</strong></h1>

# %% [markdown]
# <a id="1.1"></a>
# # ️🎯 1.1 Introduction
# ****
#
# <p style="list-style-type:circle;font-family:Yu Mincho Demibold;font-size:20px;color:black"> Human health is one of the most critical fields in the world. Exploring the way to prevent and detect the health disease which therefore raised a lot of attractions. The most major disease which heavily affects human health is cancer. Malignant tumor is the consequence of cancer. Along with breast cancer , lung cancer, colon cancer is reported to be the third deadliest cancer in the United States which causes 49,190 U.S. lives in 2016 [1]. This is a type of cancer that starts in the large intestine colon which is the final part of the digestive tract.</p>
#
#
# <p style="list-style-type:circle;font-family:Yu Mincho Demibold;font-size:20px;color:black"> In this project, the machine learning model must be implemented to help detecting the cancerous cell and differentiating the cell types for colon cancer. XGBoost is the only non deep learning approach to solve the problem and deep learning approaches such as AlexNet, Resnet50 and VGG19 will all be implemented and evalutated in this notebook.</p>

# %% [markdown]
# <a id="1.2"></a>
# # ✴️ 1.2 Importing Necessary Libraries and datasets
# ****

# %%
import sys
# !{sys.executable} -m pip -q install missingno

# import libraries which are pandas and numpy
import pandas as pd
import numpy as np
import missingno as msno


#for plots
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]= 15,10

#Libraries for plotting
# Modules for data visualization
import seaborn as sns
import plotly.express as px
import matplotlib.patches as mpatches
sns.set_theme(style="ticks", color_codes=True) #set theme in seaborn
# scatter matrix library
from pandas.plotting import scatter_matrix

#This is is for Correlation test
from scipy.stats import spearmanr
#This is is for Mann-Whitney Testing
import scipy.stats as stats

#Libraries for feature scaling
from sklearn.preprocessing import StandardScaler

#Libraries for Validation
from sklearn.utils.multiclass import unique_labels
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score

from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

#Libraries for Training model

# %% [markdown]
# ## Check numpy and pandas version

# %%
# check the version of the packages
print("Numpy version: ", np.__version__)
print("Pandas version: ",pd.__version__)
! python --version
# Out:
# Numpy version:  1.21.5
# Pandas version:  1.4.2
# Python 3.9.12

# %% [markdown]
# ### ------------> OBSERVATION
# ***
# I want to check the numpy and pandas version since I want to make sure the verson is appropriate for my work load. Currently, it is still appropriate

# %% [markdown]
# <a id="1.3"></a>
# # 📲 1.3 Data Retrieving
# ***

# %% [markdown]
# > **Sample label Dataset**

# %%
df_label = pd.read_csv("Data/data_labels_mainData.csv", delimiter=',', skipinitialspace = True)

df_label.columns = df_label.columns.str.replace(' ', '') #strip the extra-whitespaces out

print("The shape of the ORGINAL data is (row, column):", str(df_label.shape))

# drop Unnamed, it is just a number given to identify each house
df_label.head(3)
# Out:
# The shape of the ORGINAL data is (row, column): (9896, 6)
#    InstanceID  patientID  ImageName cellTypeName  cellType  isCancerous
# 0       22405          1  22405.png   fibroblast         0            0
# 1       22406          1  22406.png   fibroblast         0            0
# 2       22407          1  22407.png   fibroblast         0            0

# %% [markdown]
# > **Sample extra_label Dataset**

# %%
df_label_extra = pd.read_csv("Data/data_labels_extraData.csv", delimiter=',', skipinitialspace = True)

df_label_extra.columns = df_label_extra.columns.str.replace(' ', '') #strip the extra-whitespaces out

print("The shape of the ORGINAL data is (row, column):", str(df_label.shape))

# drop Unnamed, it is just a number given to identify each house
df_label_extra.head(3)
# Out:
# The shape of the ORGINAL data is (row, column): (9896, 6)
#    InstanceID  patientID  ImageName  isCancerous
# 0       12681         61  12681.png            0
# 1       12682         61  12682.png            0
# 2       12683         61  12683.png            0

# %% [markdown]
# <a id="1.4"></a>
# # 🔈 1.4 Data Information
# ****
# I want to have an overall look on both of the train and test dataset, so I use .shape and .info() function in python to do that.

# %% [markdown]
# > **Sample label Dataset**

# %%
print ("The shape of the train data is (row, column):"+ str(df_label.shape))
print (df_label.info())
# Out:
# The shape of the train data is (row, column):(9896, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9896 entries, 0 to 9895
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   InstanceID    9896 non-null   int64
#  1   patientID     9896 non-null   int64
#  2   ImageName     9896 non-null   object
#  3   cellTypeName  9896 non-null   object
#  4   cellType      9896 non-null   int64
#  5   isCancerous   9896 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 464.0+ KB
# None

# %% [markdown]
# ### ------------> OBSERVATION
# ***
# From this, the information that I gained from the train dataset are the total paitent record is 599 with no missing and it has 11 columns with the target variable `Sepsis.

# %% [markdown]
# > **Sample extra_label Dataset**

# %%
print ("The shape of the train data is (row, column):"+ str(df_label_extra.shape))
print (df_label_extra.info())
# Out:
# The shape of the train data is (row, column):(10384, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10384 entries, 0 to 10383
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InstanceID   10384 non-null  int64
#  1   patientID    10384 non-null  int64
#  2   ImageName    10384 non-null  object
#  3   isCancerous  10384 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 324.6+ KB
# None

# %% [markdown]
# ### ------------> OBSERVATION
# ***
# From this, the information that I gained from the train dataset are the total paitent record is 599 with no missing and it has 11 columns with the target variable `Sepsis.

# %% [markdown]
# <a id="2"></a>
# <h1 style="color:#ffc0cb;font-size:40px;font-family:Georgia;text-align:center;"><strong> 🧹 2. Data Cleaning</strong></h1>

# %% [markdown]
# <a id="2.1"></a>
# # 🦄 2.1 About This Dataset
# ***
#
# <p style="list-style-type:circle;font-family:Yu Mincho Demibold;font-size:20px;color:black"> In this assignment, it is given two csv files which are the main and the extra file along with the patch of cell images. Each image is a 27 x 27 x 3 (RGB) size which is already modified by the lecturer. These two files and images are taken from 99 patients which split the first 60 patient-images' information into the main dataset and the last 39 patient-images. For the main data set, this file contains the information of 9896 cells while the extra dataset has 10384 cells’ information. The only difference between these two datasets is the extra dataset does not have the cellType and cellTypeName columns compared to the main dataset while both datasets have patientID, ImageName and isCancerous (determine whether this cell is cancerous or not).
# </p>
#
# <p style="list-style-type:circle;font-family:Yu Mincho Demibold;font-size:20px;color:black"> As can be seen below in the main dataset (the exploration), the difference between the number of cancerous and non-cancerous cells is approximately 2000 units, the number of non-cancerous cells is 5817 while the number of cancerous cells is 4079. In the extra dataset, the number of non-cancerous cells is more than twice the number of cancerous cells which is 7394 compared to 2990 units.
#
# </p>
